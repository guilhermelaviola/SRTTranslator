# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/SRTTranslator/blob/main/PortugueseSRTCorrector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pysrt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13443 sha256=18e14df9690c57bae2a450e96d20059a6658f7d523dd2fdfbd3b4a714c9474d9
#   Stored in directory: /root/.cache/pip/wheels/6a/36/54/2aa8dc961885dfa7b0ebd45a57505f25039d79b4ea0fd9f29d
# Successfully built pysrt
# ...

# %%
import pysrt
from transformers import pipeline
import time

# Load the SRT file
srt_file_path = 'input.srt'
output_file_path = 'corrected.srt'

subs = pysrt.open(srt_file_path, encoding='utf-8')

# Loading a grammar correction model for Portuguese.
# Note: It's possible to try different models; this one is generic for text2text in Portuguese:
corrector = pipeline("text2text-generation", model="unicamp-dl/ptt5-base-portuguese-vocab")

# Correcting text using the model:
def correct_text(text):
    prompt = f'Correct this sentence: {text}'
    try:
        result = corrector(prompt, max_length=128, do_sample=False)[0]['generated_text']
        return result
    except Exception as e:
        print(f'Error correcting: {text}\n{e}')
        return text  # fallback

# Applying correction to all subtitles:
for i, sub in enumerate(subs):
    original = sub.text.replace('\n', ' ')
    corrected = correct_text(original)
    sub.text = corrected
    time.sleep(0.2)  # to avoid overloading the model if using API

# Saving the corrected subtitles:
subs.save(output_file_path, encoding='utf-8')
print(f'✅ The file has been corrected and saved as: {output_file_path}')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/456 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/756k [00:00<?, ?B/s]
# ...

# %% [markdown]
# The error you encountered, `ModuleNotFoundError: No module named 'language_tool_python'`, indicates that the Python package `language_tool_python` is not installed in your current environment.
#
# To fix this, you need to install the package using `pip`. The cell above does this by running the command `!pip install language_tool_python`. Once this cell has been executed successfully, you can run the original code cell again, and the import error should be resolved.
